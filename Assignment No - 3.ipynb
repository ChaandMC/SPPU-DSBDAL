# %%
import numpy as np
import pandas as pd
import matplotlib as matp
import seaborn as sns
# %matplotlib inline

# %%
iris = pd.read_csv("iris.csv")

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.groupby('species').sepal_length.agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#             min  max   mean  median       std
# species
# setosa      4.3  5.8  5.006     5.0  0.352490
# versicolor  4.9  7.0  5.936     5.9  0.516171
# virginica   4.9  7.9  6.588     6.5  0.635880

# %%
iris.groupby('species').sepal_width.agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#             min  max   mean  median       std
# species
# setosa      2.3  4.4  3.418     3.4  0.381024
# versicolor  2.0  3.4  2.770     2.8  0.313798
# virginica   2.2  3.8  2.974     3.0  0.322497

# %%
iris.groupby('species').petal_length.agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#             min  max   mean  median       std
# species
# setosa      1.0  1.9  1.464    1.50  0.173511
# versicolor  3.0  5.1  4.260    4.35  0.469911
# virginica   4.5  6.9  5.552    5.55  0.551895

# %%
iris.groupby('species').petal_width.agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#             min  max   mean  median       std
# species
# setosa      0.1  0.6  0.244     0.2  0.107210
# versicolor  1.0  1.8  1.326     1.3  0.197753
# virginica   1.4  2.5  2.026     2.0  0.274650

# %%
iris.groupby('species').sepal_length.min()
# Out:
# species
# setosa        4.3
# versicolor    4.9
# virginica     4.9
# Name: sepal_length, dtype: float64

# %%
iris.groupby('species').sepal_length.max()
# Out:
# species
# setosa        5.8
# versicolor    7.0
# virginica     7.9
# Name: sepal_length, dtype: float64

# %%
iris.groupby('species').sepal_length.mean()
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
iris.groupby('species').sepal_length.median()
# Out:
# species
# setosa        5.0
# versicolor    5.9
# virginica     6.5
# Name: sepal_length, dtype: float64

# %%
iris.groupby('species').sepal_length.std()
# Out:
# species
# setosa        0.352490
# versicolor    0.516171
# virginica     0.635880
# Name: sepal_length, dtype: float64

# %%
iris.groupby('species').sepal_length.var()
# Out:
# species
# setosa        0.124249
# versicolor    0.266433
# virginica     0.404343
# Name: sepal_length, dtype: float64
