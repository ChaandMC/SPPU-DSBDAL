# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
data=pd.read_csv("titanic-training-data.csv")
df=pd.DataFrame(data)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=df.replace(to_replace=(0,1), value=('D','A'))

# %%
print(df)
# Out:
#     PassengerId Survived Pclass  \
# 0             A        D      3
# 1             2        A      A
# 2             3        A      3
# 3             4        A      A
# 4             5        D      3
# ..          ...      ...    ...
# 886         887        D      2
# 887         888        A      A
# 888         889        D      3
# 889         890        A      A
# 890         891        D      3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     A
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     A
# 2                               Heikkinen, Miss. Laina  female  26.0     D
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     A
# 4                             Allen, Mr. William Henry    male  35.0     D
# ..                                                 ...     ...   ...   ...
# ...

# %%
df['Survived']=df['Survived'].replace(to_replace=(0,1), value=('D','A'))

# %%
df
# Out:
#     PassengerId Survived Pclass  \
# 0             A        D      3
# 1             2        A      A
# 2             3        A      3
# 3             4        A      A
# 4             5        D      3
# ..          ...      ...    ...
# 886         887        D      2
# 887         888        A      A
# 888         889        D      3
# 889         890        A      A
# 890         891        D      3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     A
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     A
# 2                               Heikkinen, Miss. Laina  female  26.0     D
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     A
# 4                             Allen, Mr. William Henry    male  35.0     D
# ..                                                 ...     ...   ...   ...
# ...

# %%
dummies=pd.get_dummies(df.Survived)

# %%
A=pd.concat([df,dummies],axis=1)

# %%
A
# Out:
#     PassengerId Survived Pclass  \
# 0             A        D      3
# 1             2        A      A
# 2             3        A      3
# 3             4        A      A
# 4             5        D      3
# ..          ...      ...    ...
# 886         887        D      2
# 887         888        A      A
# 888         889        D      3
# 889         890        A      A
# 890         891        D      3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     A
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     A
# 2                               Heikkinen, Miss. Laina  female  26.0     D
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     A
# 4                             Allen, Mr. William Henry    male  35.0     D
# ..                                                 ...     ...   ...   ...
# ...

# %%
dummies=pd.get_dummies(df,columns=['Survived'],dtype=int)

# %%
A=pd.concat([df,dummies],axis=1)

# %%
A
# Out:
#     PassengerId Survived Pclass  \
# 0             A        D      3
# 1             2        A      A
# 2             3        A      3
# 3             4        A      A
# 4             5        D      3
# ..          ...      ...    ...
# 886         887        D      2
# 887         888        A      A
# 888         889        D      3
# 889         890        A      A
# 890         891        D      3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     A
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     A
# 2                               Heikkinen, Miss. Laina  female  26.0     D
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     A
# 4                             Allen, Mr. William Henry    male  35.0     D
# ..                                                 ...     ...   ...   ...
# ...

# %%
df['Fare'].head(10)
# Out:
# 0       7.25
# 1    71.2833
# 2      7.925
# 3       53.1
# 4       8.05
# 5     8.4583
# 6    51.8625
# 7     21.075
# 8    11.1333
# 9    30.0708
# Name: Fare, dtype: object

# %%
df['Fare'] = df['Fare'].replace('A', np.nan)

# %%
df = df[df['Fare'] != 'D']
df['Fare'] = pd.to_numeric(df['Fare'])
# Out:
# <ipython-input-114-ef5df6e7a5aa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fare'] = pd.to_numeric(df['Fare'])

# %%
df['Fare'] = df['Fare'].replace('D', '0')
df['Fare'] = pd.to_numeric(df['Fare'])
# Out:
# <ipython-input-115-277d48d88adf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fare'] = df['Fare'].replace('D', '0')
# <ipython-input-115-277d48d88adf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fare'] = pd.to_numeric(df['Fare'])

# %%
sns.displot(df['Fare'])

# %%
df['Age'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: object

# %%
df['Age'] = df['Age'].replace('A', np.nan)
# Out:
# <ipython-input-118-b3cf290aea99>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = df['Age'].replace('A', np.nan)

# %%
df['Age'] = pd.to_numeric(df['Age'])
# Out:
# <ipython-input-119-10842d8622e5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = pd.to_numeric(df['Age'])

# %%
sns.displot(df['Age'])

# %%
df.describe()
# Out:
#               Age        Fare
# count  700.000000  876.000000
# mean    29.931671   32.755650
# std     14.345173   49.936826
# min      0.420000    4.012500
# 25%     21.000000    7.925000
# 50%     28.000000   14.500000
# 75%     38.000000   31.275000
# max     80.000000  512.329200

# %%
df.head()
# Out:
#   PassengerId Survived Pclass  \
# 0           A        D      3
# 1           2        A      A
# 2           3        A      3
# 3           4        A      A
# 4           5        D      3
#
#                                                 Name     Sex   Age SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0     A
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     A
# 2                             Heikkinen, Miss. Laina  female  26.0     D
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     A
# 4                           Allen, Mr. William Henry    male  35.0     D
#
#   Parch            Ticket     Fare Cabin Embarked
# 0     D         A/5 21171   7.2500   NaN        S
# 1     D          PC 17599  71.2833   C85        C
# 2     D  STON/O2. 3101282   7.9250   NaN        S
# 3     D            113803  53.1000  C123        S
# 4     D            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#               Age        Fare
# count  700.000000  876.000000
# mean    29.931671   32.755650
# std     14.345173   49.936826
# min      0.420000    4.012500
# 25%     21.000000    7.925000
# 50%     28.000000   14.500000
# 75%     38.000000   31.275000
# max     80.000000  512.329200

# %%
df['Sex']=df['Sex'].str.upper()
# Out:
# <ipython-input-124-d46d4a8c0332>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sex']=df['Sex'].str.upper()

# %%
df_filtered = df[df['Age'] > 20]

# %%
print(df.head())
# Out:
#   PassengerId Survived Pclass  \
# 0           A        D      3
# 1           2        A      A
# 2           3        A      3
# 3           4        A      A
# 4           5        D      3
#
#                                                 Name     Sex   Age SibSp  \
# 0                            Braund, Mr. Owen Harris    MALE  22.0     A
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  FEMALE  38.0     A
# 2                             Heikkinen, Miss. Laina  FEMALE  26.0     D
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  FEMALE  35.0     A
# 4                           Allen, Mr. William Henry    MALE  35.0     D
#
#   Parch            Ticket     Fare Cabin Embarked
# 0     D         A/5 21171   7.2500   NaN        S
# 1     D          PC 17599  71.2833   C85        C
# 2     D  STON/O2. 3101282   7.9250   NaN        S
# 3     D            113803  53.1000  C123        S
# 4     D            373450   8.0500   NaN        S

# %%
datatypes = df.dtypes

# %%
datatypes
# Out:
# PassengerId     object
# Survived        object
# Pclass          object
# Name            object
# Sex             object
# Age            float64
# SibSp           object
# Parch           object
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data_types_dict = {'PassengerId':str}

# %%
df = df.astype(data_types_dict)

# %%
df.dtypes
# Out:
# PassengerId     object
# Survived        object
# Pclass          object
# Name            object
# Sex             object
# Age            float64
# SibSp           object
# Parch           object
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
